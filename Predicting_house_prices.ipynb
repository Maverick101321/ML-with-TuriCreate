# %% [markdown]
# # Launching Turi Create

# %%
import turicreate

# %% [markdown]
# # Load house sales data

# %%
sales = turicreate.SFrame('home_data.sframe/home_data.sframe')

# %%
sales.head()
# just typing sales also gives the same result
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 10
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
sales.tail()
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 10
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7852140040 | 2014-08-25 00:00:00+00:00 |  507250.0 |   3.0    |    2.5    |
# | 9834201367 | 2015-01-26 00:00:00+00:00 |  429000.0 |   3.0    |    2.0    |
# | 3448900210 | 2014-10-14 00:00:00+00:00 |  610685.0 |   4.0    |    2.5    |
# | 7936000429 | 2015-03-26 00:00:00+00:00 | 1007500.0 |   4.0    |    3.5    |
# ...

# %% [markdown]
# # Visualising the dataset by using show()

# %%
sales.show()
# Out:
# Materializing SFrame
# ...
# Further warnings of unsupported type will be suppressed.
# ...

# %%
turicreate.show(sales[1:5000]['sqft_living'], sales[1:5000]['price'])
# x is the sqrt_living and y is the price
# took the first 5000 rows of the dataset
#This will creata a scatter plot taking the first 5k rows of the dataset
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %%
#Naming the x and the y axis for better understanding can be done by xlable and y lable
turicreate.show(sales[1:5000]['sqft_living'], sales[1:5000]['price'], xlabel = 'Square ft of living space', ylabel = 'Cost of Property in USD')
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %%
#If the value of rows selected is greater than 5k than turicreate shows the data in the form of a heat map
turicreate.show(sales[1:5100]['sqft_living'], sales[1:5100]['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %% [markdown]
# # Simple regression model that predicts price from square feet

# %% [markdown]
# ## Splitting the dataset into training and test data

# %%
#Splitting the dataset into training_data and testing_data, keeping 80% for training and rest for testing
training_set, test_set = sales.random_split(.8,seed=0)

# %% [markdown]
# ## Training a simple regression model

# %%
# sqft_regression_model is the name of the model
# inside the bracket firstly we put the data to be used as input
# target defines the variable that we're trying to predict
# features defines what part(column) of the training data to be used as input
# in case we dont give anything in features then it will automatically use all columns of the data
sqft_regression_model = turicreate.linear_regression.create(training_set, target='price', features=['sqft_living'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %% [markdown]
# # Evaluating the quality of our model

# %%
#printing the average price in the test dataset
print (test_set['price'].mean())
#we used print fn here cause it usually gives out the format in a proper way that is undersytandable
# Out:
# 543054.0425632538

# %%
#same cmd without print fn
test_set['price'].mean()
# Out:
# 543054.0425632538

# %%
#this gives out the 
#1. max error tells the maximum error between the test_data value and the predicted value
#2. root mean square error between the test data value and the predicted value
print (sqft_regression_model.evaluate(test_set))
#as we can see below that both the max error and the rmse are very high for the model
# Out:
# {'max_error': 4152951.103706922, 'rmse': 255164.20272938552}

# %% [markdown]
# # Exploring the model a little further

# %%
sqft_regression_model.coefficients
#the above line of code returns the coefficient of the linear regression model
#in other word the relationship between the features and the target variable
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+--------------------+--------------------+
# |     name    | index |       value        |       stderr       |
# +-------------+-------+--------------------+--------------------+
# | (intercept) |  None | -44464.21232618438 |  5027.46713628794  |
# | sqft_living |  None | 280.7394447542227  | 2.2082561768717586 |
# +-------------+-------+--------------------+--------------------+
# [2 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#the above line is to show all the plotting in this notebook

# %%
plt.plot(test_set['sqft_living'], test_set['price'], '.', 
         test_set['sqft_living'], sqft_regression_model.predict(test_set), '-')

# %% [markdown]
# # Exploring other important features of the dataset

# %%
my_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','zipcode']
#exploring other significant features in deciding the price of the property

# %%
sales[my_features].show()
# Out:
# Materializing SFrame
# ...

# %%
turicreate.show(sales['zipcode'],sales['price'], xlabel = 'zipcodes', ylabel = 'prices of properties in zipcode')
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %% [markdown]
# # Build a model with these additional features

# %%
my_features_model = turicreate.linear_regression.create(training_set,target='price',features=my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 75
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %% [markdown]
# # Compare simple model with more complex one

# %%
print (my_features)
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
my_features
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
print (sqft_regression_model.evaluate(test_set))
print (my_features_model.evaluate(test_set))
#we can see that the max_error and the rmse both have gone done with the increase in the number of features being used.
# Out:
# {'max_error': 4152951.103706922, 'rmse': 255164.20272938552}
# {'max_error': 3174306.7954404284, 'rmse': 180448.47458096166}

# %% [markdown]
# # Apply learned models to make predictions

# %%
house1 = sales[sales['id']=='5309101200']
#assigning the variable to a specific house from the dataset

# %%
house1
#this will show all the details present in the db related to the house
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+----------+----------+-----------+
# |     id     |            date           |  price   | bedrooms | bathrooms |
# +------------+---------------------------+----------+----------+-----------+
# | 5309101200 | 2014-06-05 00:00:00+00:00 | 620000.0 |   4.0    |    2.25   |
# +------------+---------------------------+----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src="http://blue.kingcounty.com/Assessor/eRealProperty/MediaHandler.aspx?Media=2916871">

# %%
print (house1['price'])
# Out:
# [620000.0, ... ]

# %%
house1['price']
#this is why we use the print fn
# Out:
# dtype: float
# Rows: ?
# [620000.0, ... ]

# %%
print (sqft_regression_model.predict(house1))
# Out:
# [629310.4550839501]

# %%
print (my_features_model.predict(house1))
# Out:
# [729848.1157189106]

# %% [markdown]
# #### We see that the model with only the sqft as a feature has predicted the price better than the model with numerous features.

# %% [markdown]
# ## Prediction for a second house, a fancier one

# %%
house2 = sales[sales['id']=='1925069082']

# %%
house2
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 1925069082 | 2015-05-11 00:00:00+00:00 | 2200000.0 |   5.0    |    4.25   |
# +------------+---------------------------+-----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src="https://ssl.cdn-redfin.com/photo/1/bigphoto/302/734302_0.jpg">

# %%
print (house2['price'])
# Out:
# [2200000.0]

# %%
print (sqft_regression_model.predict(house2))
# Out:
# [1258166.8113334088]

# %%
print (my_features_model.predict(house2))
# Out:
# [1235329.1695312588]

# %% [markdown]
# ## Prediction for a super fancy home

# %%
bill_gates_house_cali = {'bedrooms':[8], 
              'bathrooms':[25], 
              'sqft_living':[50000], 
              'sqft_lot':[225000],
              'floors':[4], 
              'zipcode':['98039'], 
              'condition':[10], 
              'grade':[10],
              'waterfront':[1],
              'view':[4],
              'sqft_above':[37500],
              'sqft_basement':[12500],
              'yr_built':[1994],
              'yr_renovated':[2010],
              'lat':[47.627606],
              'long':[-122.242054],
              'sqft_living15':[5000],
              'sqft_lot15':[40000]}

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/26/Residence_of_Bill_Gates.jpg">

# %%
print (my_features_model.predict(turicreate.SFrame(bill_gates_house_cali)))
# Out:
# [14985004.075212747]

# %%
print (sqft_regression_model.predict(turicreate.SFrame(bill_gates_house_cali)))
# Out:
# [13992508.025384951]

# %% [markdown]
# # Completed
